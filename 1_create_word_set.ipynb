# %%
import pandas as pd
import os
import sys
import pickle
import datetime
import time
import re
from sqlalchemy import create_engine
from sqlalchemy import text
import sqlalchemy
import psycopg2

# %%
STOP_WORDS = { "the",
    "and", "or", "the", "a", "an", "to", "of", "in", "on", "for", "with",
    "by", "at", "from", "as", "is", "are", "this", "that", 'tv', 'collection',
    'episodes' ,'episode', 'и', 'ну', 'не', 'ссср','shorts', 'y', 'kidsmania',
    'un', 'el', 'de', 'be', 'episodio'
}

# %%
#
def tokenize_clean(text):
    tokens = re.findall(r"\b[^\W_]+\b", text.lower(), flags=re.UNICODE)
    return [ t.strip() for t in tokens if not t.isdigit() and t not in STOP_WORDS ]

# %%
def get_intersect_ch(in_sentence, unigrams_s):
    #print('in_sentence', in_sentence)
    in_set = set(in_sentence)
    return(len(list(unigrams_s.intersection(in_set))))

# %%
def get_intersect(in_sentence, unigrams_s):
    in_set = set(in_sentence)
    return(list(unigrams_s.intersection(in_set)))

# %%
# Получаем исходные данные

# %%
conn_string = os.environ['PG_DB2']
db = create_engine(conn_string.replace('multdb', 'youtube'))
conn = db.connect()
req1 = '''select iyr.yt_reel_id, reel_name, yt_ch_name, cartoon, brand_id, product_id,language from intl_yt_reels iyr 
join intl_yt_channels2reels iyrcr 
on iyr.yt_reel_id = iyrcr.yt_reel_id 
join intl_yt_channels iyc 
on iyrcr.yt_ch_id = iyc.yt_ch_id 
where iyc."language" in ('США','Английский', 'Испанский', 'Арабский', 'Португальский','Китайский')
and iyr.removed = 0  '''
df_sql = pd.read_sql(text(req1), conn)
conn.close()

# %% [markdown]
# # Get uni and bigrams

# %%
# check "our" and "foreign" reels

# %%
print(len(df_sql[df_sql.product_id != '']))
print(len(df_sql[df_sql.product_id == '']))
# Out:
# 3980
# 58829

# %%
# В качестве исходника берем не только название рила, но и название канала на которым он выложен:

# %%
df_sql['name'] = df_sql.yt_ch_name + ' '+df_sql.reel_name

# %%
df_sql["tokens"] = df_sql["name"].apply(tokenize_clean)

# %%
# Формируем список tokens для обоих вариантов

# %%
plus_scs = df_sql[df_sql.product_id != ''].tokens.to_list()
minus_scs = df_sql[df_sql.product_id == ''].tokens.to_list()

# %%
# Получаем список слов

# %%
plus_words = [word.strip('.,:-').lower() for line in plus_scs for word in line]
minus_words = [word.strip('.,:-').lower()for line in minus_scs for word in line]

# %%
words_differ = set(plus_words) - set(minus_words)
len(words_differ)
# Out:
# 769

# %%
# Итак, вот столько слов отличает оба списка и являются базой для разметки рилов

# %%
# Посмотрим частоту использования каждого слова для разметки:

# %%
result = pd.DataFrame({'word': plus_words})

result_df = (result['word'].value_counts().rename_axis('keyword').reset_index(name='count'))

result_df = result_df[result_df['keyword'].isin(words_differ)]
display(result_df.head(5))
# Out:
#        keyword  count
# 1     rockoons   1672
# 3   musipaches   1207
# 11    naranjas    830
# 17        مشمش    474
# 27         moo    280

# %%
print("All words:", len(result_df))
print("Single reel words:", len(result_df[result_df['count']==1]))
display(result_df.head(5))
display(result_df.tail(5))
# Out:
# All words: 769
# Single reel words: 479
#        keyword  count
# 1     rockoons   1672
# 3   musipaches   1207
# 11    naranjas    830
# 17        مشمش    474
# 27         moo    280
#                keyword  count
# 2280  rocksongsforkids      1
# 2282           wheater      1
# 2283            menudo      1
# 2285              rara      1
# 2291           summers      1

# %%
# Bigrams

# %%
df_sql["bigrams"] = df_sql["tokens"].apply(lambda x: list(zip(x, x[1:])))
plus_bigrams = df_sql[df_sql.product_id != '']["bigrams"].explode().dropna().tolist()
minus_bigrams = df_sql[df_sql.product_id == '']["bigrams"].explode().dropna().tolist()
bigrams_differ = set(plus_bigrams)-set(minus_bigrams)
print(len(bigrams_differ))
# Out:
# 5260

# %%
result = pd.DataFrame({'bi_word': plus_bigrams})

bigrams_df = (result['bi_word'].value_counts().rename_axis('keyword').reset_index(name='count'))

bigrams_df = bigrams_df[bigrams_df['keyword'].isin(bigrams_differ)]
display(bigrams_df.head(5))
# Out:
#                     keyword  count
# 1              (las, vacas)    830
# 2         (vacas, naranjas)    830
# 7             (عائلة, مشمش)    389
# 8  (musipaches, musipaches)    367
# 9      (rockoons, rockoons)    360

# %%
print("All bigrams:", len(bigrams_df))
print("Single reel bigrams:", len(bigrams_df[bigrams_df['count']==1]))
display(bigrams_df.head(5))
display(bigrams_df.tail(5))
# Out:
# All bigrams: 5260
# Single reel bigrams: 3648
#                     keyword  count
# 1              (las, vacas)    830
# 2         (vacas, naranjas)    830
# 7             (عائلة, مشمش)    389
# 8  (musipaches, musipaches)    367
# 9      (rockoons, rockoons)    360
#                      keyword  count
# 6249   (witches, adventures)      1
# 6251  (tallest, claymotions)      1
# 6253         (summer, midst)      1
# 6254         (midst, winter)      1
# 6255         (winter, oomka)      1

# %% [markdown]
# # Clean unigram list

# %%
# get reels that were marked by more than one unigram (word)

# %%
unigrams_final = result_df.copy()

# %%
unigrams_set = set(unigrams_final.keyword.to_list())

# %%
reels_plus =  df_sql[df_sql.product_id != ''].copy()

# %%
reels_plus['ch2_unigrams'] = reels_plus['tokens'].apply(get_intersect_ch, args=(unigrams_set,))

# %%
reels_multi = reels_plus[reels_plus.ch2_unigrams >  1].copy() # was >1

# %%
# Let's get these words for each reel (intersection with unigrams_set):

# %%
reels_multi['unigrams'] = reels_plus['tokens'].apply(get_intersect, args=(unigrams_set,)) 
reels_multi = reels_multi[['yt_reel_id', 'tokens', 'unigrams', 'ch2_unigrams']]

# %%
# and get unique list of unigrams, that used more then one time for markup

# %%
unigrams_multi = reels_multi['unigrams'].to_list()
unigrams_multi_set = set([ i for j in unigrams_multi  for i in j ] )
print(len(unigrams_multi_set))
# Out:
# 722

# %%
# let's make dict kind of: word, list of reel_ids that this word marked

# %%
unigram2reels = {}
for unigram in unigrams_multi_set:
    df_temp = reels_multi[reels_multi['tokens'].apply(lambda x: isinstance(x, list) and unigram in x)]
    unigram2reels[unigram] = set(df_temp.yt_reel_id.to_list())

# %%
subset_keys = [ k for k, v in unigram2reels.items()
    if not any( v < other_v for other_k, other_v in unigram2reels.items() if other_k != k ) ]  # strict subset, exclude itself

# %%
print(len(subset_keys))
# Out:
# 86

# %%
##############

# %%
unigrams_final_set = set(subset_keys)

# %%
df_unigram2reels = pd.DataFrame( [(k, list(v)) for k, v in unigram2reels.items()], columns=['unigram', 'id'])

df_unigram2reels.columns = ['unigramm', 'ids']
df_unigram2reels['ids_num'] = df_unigram2reels['ids'].apply(len)

# %%
to_remove = []
for i in range(len(unigrams_final_set)):
    bi_1 = list(unigrams_final_set)[i]
    for j in range(i+1,len(unigrams_final_set)):
        bi_2 =  list(unigrams_final_set)[j]
        a = set(df_unigram2reels[df_unigram2reels.unigramm == bi_1].ids.to_list()[0])
        b = set(df_unigram2reels[df_unigram2reels.unigramm == bi_2].ids.to_list()[0])
        if(a == b):
            print(bi_1, bi_2)
            to_remove.append(bi_2)
# Out:
# deadbone sitcom
# gamayun prophet
# سأمسك الأذى
# даша людоед
# caramba apr23
# caramba graciosas
# drago trihead
# apr23 graciosas
# valle miel
# casino caper
# goddesses erinyes
# المتحرك الصلصال
# deeds journal
# tzar firebird
# 彩泥行动 我们在学习数数
# kidnapping hoglets

# %%
unigrams_final_set = (unigrams_final_set - set(to_remove))

# %%
##### Remove unigrams that detects single yt_reel_id

# %%
single_set = set(df_unigram2reels[df_unigram2reels['ids_num'] < 6].unigramm.to_list()) # really ???? was == 1 

print(len(single_set))
# Out:
# 606

# %%
single_set = set(df_unigram2reels[df_unigram2reels['ids_num'] < 6].unigramm.to_list()) # really ???? was == 1 
print(len(single_set))
print(len(unigrams_final_set))
unigrams_final_set = unigrams_final_set - unigrams_final_set.intersection(single_set)
print(len(unigrams_final_set))
# Out:
# 606
# 71
# 39

# %%
#unigrams_final_set

# %% [markdown]
# # Clean bigrams from those that contains unigrams from set

# %%
bigrams_df['words_exst'] = bigrams_df.keyword.apply(lambda x: x[0] in unigrams_final_set or x[1] in unigrams_final_set)

bigrams_df[(bigrams_df['words_exst'] == False) & (bigrams_df['count'] > 3) ].head(3)
# Out:
#                     keyword  count  words_exst
# 1              (las, vacas)    830       False
# 29  (infantiles, canciones)    192       False
# 31         (عائلة, أبريكوت)    162       False

# %%
bigrams_df[(bigrams_df['words_exst'] == True)].sample(3)
# Out:
#                   keyword  count  words_exst
# 3774          (مشمش, لغز)      1        True
# 1402  (rockoons, theatre)      2        True
# 3030  (marionetas, lápiz)      1        True

# %%
# Разметили биграммы - теперь есть отметка тех, где используются униграммы - те которые можно убрать

#unigrams_final = unigrams_df.copy()
bigrams_final = bigrams_df.copy()

# %%
len(bigrams_final[bigrams_final.words_exst == False]) # words_exst == True - don't use
# Out:
# 3936

# %%
bigrams_final
# Out:
#                        keyword  count  words_exst
# 1                 (las, vacas)    830       False
# 2            (vacas, naranjas)    830        True
# 7                (عائلة, مشمش)    389        True
# 8     (musipaches, musipaches)    367        True
# 9         (rockoons, rockoons)    360        True
# ...                        ...    ...         ...
# 6249     (witches, adventures)      1       False
# 6251    (tallest, claymotions)      1        True
# 6253           (summer, midst)      1       False
# 6254           (midst, winter)      1       False
# 6255           (winter, oomka)      1        True
#
# [5260 rows x 3 columns]

# %% [markdown]
# # Clean bigram list

# %%
bigrams_set = set(bigrams_final[bigrams_final.words_exst==False].keyword.to_list())

# %%
reels_plus['ch2_bigrams'] = reels_plus['bigrams'].apply(get_intersect_ch, args=(bigrams_set,)) 
reels_plus['sel_bigrams'] = reels_plus['bigrams'].apply(get_intersect, args=(bigrams_set,))

# %%
reels_multi = reels_plus[reels_plus.ch2_bigrams >  1].copy() # was >1

# %%
reels_multi = reels_multi[['yt_reel_id', 'bigrams', 'sel_bigrams', 'ch2_bigrams']]

# %%
bigrams_multi = reels_multi['sel_bigrams'].to_list()
bigrams_multi_set = set([ i for j in bigrams_multi  for i in j ] )
len(bigrams_multi_set)
# Out:
# 3446

# %%
bigram2reels = {}
for bigram in bigrams_multi_set:
    df_temp = reels_multi[reels_multi['bigrams'].apply(lambda x: isinstance(x, list) and bigram in x)]
    bigram2reels[bigram] = set(df_temp.yt_reel_id.to_list())

# %%
#bigram2reels

# %%
subset_bi_keys = [ k for k, v in bigram2reels.items()
    if not any( v < other_v for other_k, other_v in bigram2reels.items() if other_k != k ) ]  # strict subset, exclude itself

# %%
print(len(subset_bi_keys))
bigrams_final_set = set(subset_bi_keys)
# Out:
# 953

# %%
df_bigram2reels = pd.DataFrame( [(k, list(v)) for k, v in bigram2reels.items()], columns=['bigram', 'id'])

# %%
df_bigram2reels['ids_num'] = df_bigram2reels['id'].apply(len)
single_set_bi = set(df_bigram2reels[df_bigram2reels['ids_num'] < 1  ].bigram.to_list()) # was <2 !!!

print(len(single_set_bi))
print(len(bigrams_final_set))
bigrams_final_set = bigrams_final_set - bigrams_final_set.intersection(single_set_bi)
print(len(bigrams_final_set))
# Out:
# 0
# 953
# 953

# %%
to_remove = []
for i in range(len(bigrams_final_set)):
    print(i, end =' - ')
    bi_1 = list(bigrams_final_set)[i]
    for j in range(i+1,len(bigrams_final_set)):
        bi_2 =  list(bigrams_final_set)[j]
        a = set(df_bigram2reels[df_bigram2reels.bigram == bi_1].id.to_list()[0])
        b = set(df_bigram2reels[df_bigram2reels.bigram == bi_2].id.to_list()[0])
        if(a == b):
            print(bi_1, bi_2)
            to_remove.append(bi_2)
# Out:
# ('الإطلاق', 'special') ('أبريكوت', 'أحلى')
# ('الإطلاق', 'special') ('العيد', 'الكبرى')
# ('الإطلاق', 'special') ('الكبرى', 'لعائلة')
# ('الإطلاق', 'special') ('عيد', 'على')
# ('الإطلاق', 'special') ('special', 'eid')
# ('الإطلاق', 'special') ('حلقة', 'عيد')
# ('الإطلاق', 'special') ('أحلى', 'حلقة')
# ('الإطلاق', 'special') ('cow', 'مفاجأة')
# ('الإطلاق', 'special') ('لعائلة', 'أبريكوت')
# ('caracola', 'almohada') ('almohada', 'dibujos')
# ('trouble', 'nursery') ('solving', 'trouble')
# ('caracola', 'dibujos') ('plastilina', 'caracola')
# ('números', 'mágicos') ('mágicos', 'del')
# ('wind', 'instruments') ('kids', 'wind')
# ('aprenda', 'os') ('massinha', 'aprenda')
# ('aprenda', 'os') ('os', 'números')
# ('aprenda', 'os') ('números', 'massinha')
# ('aprenda', 'os') ('felizes', 'números')
# ('massinha', 'aprenda') ('os', 'números')
# ('massinha', 'aprenda') ('números', 'massinha')
# ('massinha', 'aprenda') ('felizes', 'números')
# ('pinzas', 'plastilina') ('plastilina', 'dibujos')
# ('planes', 'learn') ('transport', 'traffic')
# ('planes', 'learn') ('learn', 'transport')
# ('planes', 'learn') ('traffic', 'kids')
# ('planes', 'learn') ('cars', 'trains')
# ('planes', 'learn') ('trains', 'planes')
# ('والأخيرة', 'صخرة') ('صخرة', 'رعناء')
# ('أغاني', 'أطفال') ('أطفال', 'cartoon')
# ('whos', 'fastest') ('fastest', 'animal')
# ('whos', 'fastest') ('cartoons', 'whos')
# ('whos', 'fastest') ('animal', 'find')
# ('games', 'boys') ('boys', 'nursery')
# ('games', 'theatre') ('theatre', 'new')
# ('лентяйка', 'василиса') ('коллекция', 'лентяйка')
# ('paint', 'brushes') ('brushes', 'cartoons')
# ('colección', 'grande') ('grande', 'dibujos')
# ('roccoons', 'musical') ('kids', 'roccoons')
# ('الحلقة', 'طريقة') ('طريقة', 'للوصول')
# ('الحلقة', 'طريقة') ('للوصول', 'بدون')
# ('الحلقة', 'طريقة') ('بدون', 'خريطة')
# ('escondite', 'busca') ('busca', 'dibujos')
# ('al', 'desafío') ('risas', 'juego')
# ('al', 'desafío') ('únete', 'al')
# ('al', 'desafío') ('español', 'risas')
# ('al', 'desafío') ('desafío', 'bádminton')
# ('al', 'desafío') ('bádminton', 'los')
# ('al', 'desafío') ('juego', 'aventuras')
# ('al', 'desafío') ('aventuras', 'únete')
# ('pirates', 'abc') ('karaoke', 'pirates')
# ('concurso', 'talentos') ('mascotas', 'nuevos')
# ('concurso', 'talentos') ('para', 'mascotas')
# ('concurso', 'talentos') ('talentos', 'para')
# ('peine', 'ruedas') ('ruedas', 'dibujos')
# ('juguetes', 'bonitos') ('bonitos', 'dibujos')
# ('mascotas', 'nuevos') ('para', 'mascotas')
# ('mascotas', 'nuevos') ('talentos', 'para')
# ('gran', 'historia') ('historia', 'los')
# ('gran', 'historia') ('los', 'fideos')
# ('o', 'juguete') ('juguete', 'descubre')
# ('o', 'juguete') ('esp', 'aspiradora')
# ('o', 'juguete') ('aspiradora', 'o')
# ('o', 'juguete') ('limpia', 'con')
# ('o', 'juguete') ('más', 'limpia')
# ('animales', 'guauguau') ('guauguau', 'estreno')
# ('esperando', 'la') ('yo', 'esperando')
# ('الحلقة', 'أحجية') ('القطع', 'المئة')
# ('الحلقة', 'أحجية') ('أحجية', 'القطع')
# ('baby', 'ti') ('ti', 'new')
# ('baby', 'ti') ('games', 'baby')
# ('world', 'game') ('sleepyheads', 'orange')
# ('world', 'game') ('game', 'sleepyheads')
# ('quiet', 'loud') ('loud', 'new')
# ('count', 'super') ('number', 'count')
# ('count', 'super') ('cartoons', 'number')
# ('pirata', 'los') ('español', 'pirata')
# ('mapaches', 'episodios') ('aventuras', 'mapaches')
# ('cartoons', 'kittens') ('love', 'play')
# ('cartoons', 'kittens') ('play', 'what')
# ('cartoons', 'kittens') ('kittens', 'love')
# ('cartoons', 'kittens') ('what', 'about')
# ('apresurar', 'dibujos') ('esperar', 'apresurar')
# ('والسعادة', 'مع') ('العائلة', 'البرتقالية')
# ('والسعادة', 'مع') ('مع', 'العائلة')
# ('parte', 'entero') ('entero', 'dibujos')
# ('izquierda', 'derecha') ('derecha', 'dibujos')
# ('mood', 'adventures') ('adventures', 'nursery')
# ('migratory', 'birds') ('kids', 'migratory')
# ('animales', 'cuántas') ('cuántas', 'patas')
# ('guerra', 'los') ('nieve', 'nuevos')
# ('guerra', 'los') ('los', 'muñecos')
# ('الحلقة', 'موقع') ('موقع', 'البناء')
# ('fastest', 'animal') ('cartoons', 'whos')
# ('fastest', 'animal') ('animal', 'find')
# ('أبريكوت', 'أحلى') ('العيد', 'الكبرى')
# ('أبريكوت', 'أحلى') ('الكبرى', 'لعائلة')
# ('أبريكوت', 'أحلى') ('عيد', 'على')
# ('أبريكوت', 'أحلى') ('special', 'eid')
# ('أبريكوت', 'أحلى') ('حلقة', 'عيد')
# ('أبريكوت', 'أحلى') ('أحلى', 'حلقة')
# ('أبريكوت', 'أحلى') ('cow', 'مفاجأة')
# ('أبريكوت', 'أحلى') ('لعائلة', 'أبريكوت')
# ('paintbrushes', 'abc') ('karaoke', 'paintbrushes')
# ('new', 'things') ('things', 'nursery')
# ('animals', 'woofwoof') ('woofwoof', 'best')
# ('activities', 'new') ('games', 'activities')
# ('الحافز', 'الأسود') ('وسم', 'الحافز')
# ('الحافز', 'الأسود') ('الحلقة', 'وسم')
# ('gancho', 'imán') ('imán', 'dibujos')
# ('learning', 'rules') ('rules', 'nursery')
# ('lo', 'largo') ('lo', 'ancho')
# ('lo', 'largo') ('ancho', 'dibujos')
# ('lo', 'largo') ('largo', 'lo')
# ('vaso', 'plato') ('plato', 'dibujos')
# ('laranja', 'sintamse') ('sintamse', 'em')
# ('animais', 'mais') ('bebês', 'animais')
# ('animais', 'mais') ('filhotes', 'fofinhos')
# ('animais', 'mais') ('mais', 'adoráveis')
# ('animais', 'mais') ('massinha', 'filhotes')
# ('animais', 'mais') ('os', 'bebês')
# ('animais', 'mais') ('fofinhos', 'os')
# ('animais', 'mais') ('adoráveis', 'do')
# ('meow', 'lets') ('everything', 'about')
# ('meow', 'lets') ('learn', 'everything')
# ('meow', 'lets') ('about', 'cats')
# ('meow', 'lets') ('videos', 'meow')
# ('العيد', 'الكبرى') ('الكبرى', 'لعائلة')
# ('العيد', 'الكبرى') ('عيد', 'على')
# ('العيد', 'الكبرى') ('special', 'eid')
# ('العيد', 'الكبرى') ('حلقة', 'عيد')
# ('العيد', 'الكبرى') ('أحلى', 'حلقة')
# ('العيد', 'الكبرى') ('cow', 'مفاجأة')
# ('العيد', 'الكبرى') ('لعائلة', 'أبريكوت')
# ('vehículos', 'dinosaurios') ('animales', 'vehículos')
# ('guests', 'gone') ('world', 'guests')
# ('guests', 'gone') ('wild', 'orange')
# ('carta', 'nuevos') ('la', 'carta')
# ('plato', 'pegatina') ('pegatina', 'dibujos')
# ('fin', 'del') ('yo', 'fin')
# ('dinosaurs', 'learn') ('animals', 'dinosaurs')
# ('dishes', 'new') ('food', 'dishes')
# ('linterna', 'pincel') ('pincel', 'dibujos')
# ('peques', 'número') ('número', 'aprende')
# ('clima', 'las') ('ubicaciones', 'dibujos')
# ('clima', 'las') ('las', 'ubicaciones')
# ('play', 'dance') ('dance', 'nursery')
# ('valuable', 'cargo') ('kids', 'valuable')
# ('nuevo', 'viejo') ('viejo', 'dibujos')
# ('ill', 'get') ('get', 'you')
# ('esponja', 'escobilla') ('escobilla', 'dibujos')
# ('bowed', 'strings') ('strings', 'instruments')
# ('bowed', 'strings') ('kids', 'bowed')
# ('عائلةأريكوت', 'رسوم') ('أطفال', 'كارتون')
# ('عائلةأريكوت', 'رسوم') ('cow', 'أطفال')
# ('عائلةأريكوت', 'رسوم') ('animation', 'orangemoocow')
# ('عائلةأريكوت', 'رسوم') ('متحركة', 'animation')
# ('عائلةأريكوت', 'رسوم') ('orangemoocow', 'kids')
# ('الكبرى', 'لعائلة') ('عيد', 'على')
# ('الكبرى', 'لعائلة') ('special', 'eid')
# ('الكبرى', 'لعائلة') ('حلقة', 'عيد')
# ('الكبرى', 'لعائلة') ('أحلى', 'حلقة')
# ('الكبرى', 'لعائلة') ('cow', 'مفاجأة')
# ('الكبرى', 'لعائلة') ('لعائلة', 'أبريكوت')
# ('botones', 'maleta') ('maleta', 'dibujos')
# ('kids', 'singing') ('buttons', 'cartoon')
# ('pilotos', 'aventuras') ('caballos', 'aves')
# ('pilotos', 'aventuras') ('aves', 'pilotos')
# ('plucked', 'string') ('kids', 'plucked')
# ('plucked', 'string') ('string', 'instruments')
# ('jalar', 'empujar') ('empujar', 'dibujos')
# ('cold', 'bit') ('kids', 'not')
# ('cold', 'bit') ('not', 'cold')
# ('مبارة', 'كرة') ('كرة', 'اليد')
# ('laranja', 'presente') ('presente', 'desenhos')
# ('clay', 'educational') ('cars', 'clay')
# ('las', 'plantas') ('secretos', 'mágicos')
# ('las', 'plantas') ('mágicos', 'las')
# ('gatitos', 'estreno') ('animales', 'gatitos')
# ('juegos', 'brillantes') ('brillantes', 'dibujos')
# ('karaoke', 'lanterns') ('lanterns', 'abc')
# ('atrapar', 'dibujos') ('lanzar', 'atrapar')
# ('remember', 'new') ('forget', 'remember')
# ('عائلة', 'أبريكور') ('أبريكور', 'رسوم')
# ('عائلة', 'أبريكور') ('cow', 'كابتن')
# ('عائلة', 'أبريكور') ('كابتن', 'زوه')
# ('عائلة', 'أبريكور') ('زوه', 'عائلة')
# ('fun', 'catchy') ('catchy', 'songs')
# ('fun', 'catchy') ('crown', 'fun')
# ('friendship', 'compromise') ('compromise', 'new')
# ('meet', 'see') ('see', 'off')
# ('cenoura', 'aprenda') ('recorde', 'cenoura')
# ('cenoura', 'aprenda') ('laranja', 'recorde')
# ('sleepyheads', 'orange') ('game', 'sleepyheads')
# ('vaso', 'dibujos') ('cuchara', 'vaso')
# ('cacerola', 'dibujos') ('corona', 'cacerola')
# ('juguete', 'descubre') ('esp', 'aspiradora')
# ('juguete', 'descubre') ('aspiradora', 'o')
# ('juguete', 'descubre') ('limpia', 'con')
# ('juguete', 'descubre') ('más', 'limpia')
# ('performances', 'new') ('theatre', 'performances')
# ('learn', 'tell') ('great', 'pretender')
# ('learn', 'tell') ('pretender', 'learning')
# ('learn', 'tell') ('truth', 'orange')
# ('learn', 'tell') ('tell', 'truth')
# ('snowflakes', 'childrens') ('childrens', 'songs')
# ('ligas', 'pinzas') ('pinzas', 'dibujos')
# ('esp', 'rey') ('descubrir', 'al')
# ('esp', 'rey') ('rey', 'los')
# ('esp', 'rey') ('líder', 'música')
# ('esp', 'rey') ('para', 'descubrir')
# ('historia', 'los') ('los', 'fideos')
# ('balde', 'músicas') ('o', 'balde')
# ('rattle', 'sing') ('along', 'kids')
# ('أطفال', 'كارتون') ('cow', 'أطفال')
# ('أطفال', 'كارتون') ('animation', 'orangemoocow')
# ('أطفال', 'كارتون') ('متحركة', 'animation')
# ('أطفال', 'كارتون') ('orangemoocow', 'kids')
# ('antifaz', 'dibujos') ('piramide', 'antifaz')
# ('new', 'caroons') ('caroons', 'kids')
# ('not', 'ski') ('ski', 'not')
# ('mug', 'clouds') ('clouds', 'happiness')
# ('piramide', 'dibujos') ('baúl', 'piramide')
# ('enojado', 'amable') ('amable', 'dibujos')
# ('4super', 'toonstv') ('snowflakes', '4super')
# ('preguiça', 'toons') ('grande', 'preguiça')
# ('preguiça', 'toons') ('laranja', 'grande')
# ('objetos', 'del') ('hogar', 'dibujos')
# ('objetos', 'del') ('del', 'hogar')
# ('qué', 'animal') ('serán', 'los')
# ('qué', 'animal') ('hoy', 'dibujos')
# ('qué', 'animal') ('animal', 'serán')
# ('idéntico', 'diferente') ('diferente', 'dibujos')
# ('empathy', 'emotions') ('emotions', 'nursery')
# ('جوقة', 'غنائية') ('الحلقة', 'جوقة')
# ('في', 'قريتنا') ('العيد', 'في')
# ('numbers', 'cartoon') ('little', 'numbers')
# ('numbers', 'cartoon') ('numbers', 'learning')
# ('guauguau', 'aprende') ('español', 'guauguau')
# ('lápis', 'elástico') ('e', 'hóquei')
# ('lápis', 'elástico') ('com', 'lápis')
# ('lápis', 'elástico') ('elástico', 'e')
# ('hogar', 'dibujos') ('del', 'hogar')
# ('adventure', 'music') ('badminton', 'adventure')
# ('adventure', 'music') ('kids', 'badminton')
# ('newcartoon', 'nurseryrhymes') ('shell', 'watch')
# ('newcartoon', 'nurseryrhymes') ('wow', 'its')
# ('newcartoon', 'nurseryrhymes') ('kids', 'newcartoon')
# ('newcartoon', 'nurseryrhymes') ('how', 'amazing')
# ('newcartoon', 'nurseryrhymes') ('its', 'shell')
# ('newcartoon', 'nurseryrhymes') ('amazing', 'kids')
# ('videos', 'lantern') ('lantern', 'panic')
# ('lápis', 'músicas') ('o', 'lápis')
# ('مجموعة', 'الأذى') ('الأذى', 'احصل')
# ('مجموعة', 'الأذى') ('على', 'الأذى')
# ('مجموعة', 'الأذى') ('احصل', 'على')
# ('educativos', 'dibujos') ('juegos', 'educativos')
# ('shell', 'watch') ('wow', 'its')
# ('shell', 'watch') ('kids', 'newcartoon')
# ('shell', 'watch') ('how', 'amazing')
# ('shell', 'watch') ('its', 'shell')
# ('shell', 'watch') ('amazing', 'kids')
# ('نهاية', 'لها') ('لا', 'نهاية')
# ('نهاية', 'لها') ('الحلقة', 'احتفالات')
# ('نهاية', 'لها') ('احتفالات', 'لا')
# ('naturales', 'dibujos') ('fenómenos', 'naturales')
# ('naturales', 'dibujos') ('los', 'fenómenos')
# ('naturales', 'dibujos') ('clima', 'los')
# ('os', 'números') ('números', 'massinha')
# ('os', 'números') ('felizes', 'números')
# ('elástica', 'desenho') ('faixa', 'elástica')
# ('toys', 'new') ('beautiful', 'toys')
# ('cow', 'أطفال') ('animation', 'orangemoocow')
# ('cow', 'أطفال') ('متحركة', 'animation')
# ('cow', 'أطفال') ('orangemoocow', 'kids')
# ('cartoons', 'can') ('fly', 'find')
# ('cartoons', 'can') ('kittens', 'fly')
# ('cartoons', 'can') ('can', 'kittens')
# ('columpio', 'dibujos') ('casa', 'columpio')
# ('secretos', 'del') ('la', 'miel')
# ('popote', 'peine') ('peine', 'dibujos')
# ('fly', 'find') ('kittens', 'fly')
# ('fly', 'find') ('can', 'kittens')
# ('número', 'um') ('um', 'desenho')
# ('catchy', 'songs') ('crown', 'fun')
# ('games', 'ball') ('ball', 'nursery')
# ('我们在学习数数', '儿童搞笑卡通') ('小动物们', '小猫')
# ('我们在学习数数', '儿童搞笑卡通') ('动画片', '小动物们')
# ('caracol', 'súper') ('nuevo', 'dibujo')
# ('caracol', 'súper') ('súper', 'nuevo')
# ('free', 'time') ('time', 'new')
# ('kids', 'keyboard') ('keyboard', 'instruments')
# ('الأذى', 'احصل') ('على', 'الأذى')
# ('الأذى', 'احصل') ('احصل', 'على')
# ('عزنا', 'بطبعنا') ('السعودي', 'عزنا')
# ('grande', 'preguiça') ('laranja', 'grande')
# ('contar', 'números') ('números', 'videos')
# ('números', 'massinha') ('felizes', 'números')
# ('serán', 'los') ('hoy', 'dibujos')
# ('serán', 'los') ('animal', 'serán')
# ('كرتون', 'غنائي') ('غنائي', 'هادف')
# ('كرتون', 'غنائي') ('للبنات', 'الحان')
# ('ropa', 'para') ('para', 'invisibles')
# ('ropa', 'para') ('animales', 'ropa')
# ('defend', 'yourself') ('kids', 'defend')
# ('عيد', 'على') ('special', 'eid')
# ('عيد', 'على') ('حلقة', 'عيد')
# ('عيد', 'على') ('أحلى', 'حلقة')
# ('عيد', 'على') ('cow', 'مفاجأة')
# ('عيد', 'على') ('لعائلة', 'أبريكوت')
# ('cartoons', 'whos') ('animal', 'find')
# ('redondos', 'dibujos') ('objetos', 'redondos')
# ('get', 'set') ('ready', 'get')
# ('get', 'set') ('set', 'goooo')
# ('get', 'set') ('goooo', 'animation')
# ('number', 'count') ('cartoons', 'number')
# ('kids', 'sport') ('sport', 'cars')
# ('mágica', 'con') ('música', 'mágica')
# ('mágica', 'con') ('con', 'cuerdas')
# ('mágica', 'con') ('cuerdas', 'teclas')
# ('vehicles', 'helpers') ('helpers', 'super')
# ('خيرا', 'تحصد') ('ازرع', 'خيرا')
# ('خيرا', 'تحصد') ('تحصد', 'شرا')
# ('خيرا', 'تحصد') ('الحلقة', 'ازرع')
# ('games', 'beach') ('beach', 'new')
# ('im', 'house') ('animals', 'im')
# ('aprenda', 'e') ('brinca', 'desenhos')
# ('aprenda', 'e') ('e', 'brinca')
# ('scale', 'abc') ('karaoke', 'scale')
# ('la', 'colmena') ('colmena', 'dorada')
# ('kids', 'conductors') ('conductors', 'stick')
# ('ligas', 'dibujos') ('trapeador', 'ligas')
# ('vehicles', 'passengers') ('passengers', 'learning')
# ('libreta', 'dibujos') ('ruedas', 'libreta')
# ('nuevo', 'dibujo') ('súper', 'nuevo')
# ('acción', 'para') ('vehículos', 'mágicos')
# ('acción', 'para') ('mágicos', 'en')
# ('yo', 'tesoros') ('tesoros', 'bajo')
# ('instruments', 'kids') ('music', 'time')
# ('instruments', 'kids') ('learn', 'instruments')
# ('descubrir', 'al') ('rey', 'los')
# ('descubrir', 'al') ('líder', 'música')
# ('descubrir', 'al') ('para', 'descubrir')
# ('love', 'play') ('play', 'what')
# ('love', 'play') ('kittens', 'love')
# ('love', 'play') ('what', 'about')
# ('mug', 'sleeping') ('counting', 'sheep')
# ('mug', 'sleeping') ('sleeping', 'counting')
# ('save', 'world') ('calm', 'down')
# ('save', 'world') ('mug', 'calm')
# ('save', 'world') ('down', 'save')
# ('أثقل', 'من') ('حمل', 'الأسرار')
# ('أثقل', 'من') ('حمل', 'الأثقال')
# ('أثقل', 'من') ('الأسرار', 'أثقل')
# ('أثقل', 'من') ('الحلقة', 'حمل')
# ('أثقل', 'من') ('من', 'حمل')
# ('favoritas', 'dibujos') ('historias', 'favoritas')
# ('silbato', 'baúl') ('baúl', 'dibujos')
# ('buttons', 'abc') ('karaoke', 'buttons')
# ('frente', 'dibujos') ('detrás', 'frente')
# ('wow', 'its') ('kids', 'newcartoon')
# ('wow', 'its') ('how', 'amazing')
# ('wow', 'its') ('its', 'shell')
# ('wow', 'its') ('amazing', 'kids')
# ('aventuras', 'casitas') ('mágicas', 'para')
# ('aventuras', 'casitas') ('casitas', 'mágicas')
# ('aventuras', 'casitas') ('animales', 'aventuras')
# ('لا', 'نهاية') ('الحلقة', 'احتفالات')
# ('لا', 'نهاية') ('احتفالات', 'لا')
# ('kids', 'unusual') ('unusual', 'instruments')
# ('risas', 'juego') ('únete', 'al')
# ('risas', 'juego') ('español', 'risas')
# ('risas', 'juego') ('desafío', 'bádminton')
# ('risas', 'juego') ('bádminton', 'los')
# ('risas', 'juego') ('juego', 'aventuras')
# ('risas', 'juego') ('aventuras', 'únete')
# ('drumstick', 'abc') ('karaoke', 'drumstick')
# ('números', 'plastilina') ('caracol', 'números')
# ('números', 'plastilina') ('plastilina', 'juega')
# ('teatro', 'dibujos') ('juegos', 'teatro')
# ('cow', 'compilation') ('world', 'orange')
# ('woof', 'super') ('animals', 'woof')
# ('instrumentos', 'sorprendentes') ('sorprendentes', 'música')
# ('instrumentos', 'sorprendentes') ('música', 'en')
# ('friends', 'сartoons') ('сartoons', 'kids')
# ('juegos', 'fav') ('fav', 'dibujos')
# ('secretos', 'mágicos') ('mágicos', 'las')
# ('play', 'what') ('kittens', 'love')
# ('play', 'what') ('what', 'about')
# ('viajes', 'aventuras') ('música', 'viajes')
# ('viajes', 'aventuras') ('espaciales', 'para')
# ('race', 'orange') ('record', 'race')
# ('race', 'orange') ('carrot', 'record')
# ('race', 'orange') ('world', 'carrot')
# ('food', 'kitchen') ('kitchen', 'new')
# ('pegatina', 'trapeador') ('trapeador', 'dibujos')
# ('kids', 'plucked') ('string', 'instruments')
# ('esp', 'aspiradora') ('aspiradora', 'o')
# ('esp', 'aspiradora') ('limpia', 'con')
# ('esp', 'aspiradora') ('más', 'limpia')
# ('kids', 'not') ('not', 'cold')
# ('solo', 'video') ('en', 'solo')
# ('أبريكور', 'رسوم') ('cow', 'كابتن')
# ('أبريكور', 'رسوم') ('كابتن', 'زوه')
# ('أبريكور', 'رسوم') ('زوه', 'عائلة')
# ('gran', 'ludel') ('ludel', 'nuevos')
# ('e', 'hóquei') ('com', 'lápis')
# ('e', 'hóquei') ('elástico', 'e')
# ('campamento', 'nuevos') ('aventura', 'campamento')
# ('kids', 'nurseryrythmes') ('nurseryrythmes', 'newcartoon')
# ('birdies', 'learning') ('migratory', 'birdies')
# ('música', 'mágica') ('con', 'cuerdas')
# ('música', 'mágica') ('cuerdas', 'teclas')
# ('caracol', 'números') ('plastilina', 'juega')
# ('o', 'elástico') ('elástico', 'músicas')
# ('suitcase', 'abc') ('karaoke', 'suitcase')
# ('arriba', 'abajo') ('abajo', 'dibujos')
# ('me', 'animal') ('animal', 'cartoons')
# ('para', 'invisibles') ('animales', 'ropa')
# ('canción', 'maleta') ('maleta', 'música')
# ('canción', 'maleta') ('hora', 'empacar')
# ('canción', 'maleta') ('empacar', 'juega')
# ('canción', 'maleta') ('esp', 'hora')
# ('وسم', 'الحافز') ('الحلقة', 'وسم')
# ('hat', 'abc') ('karaoke', 'magic')
# ('العائلة', 'البرتقالية') ('مع', 'العائلة')
# ('aspiradora', 'dibujos') ('cacerola', 'aspiradora')
# ('going', 'down') ('going', 'up')
# ('going', 'down') ('up', 'going')
# ('شكرا', 'الدمية') ('الدمية', 'مروان')
# ('subir', 'bajar') ('bajar', 'dibujos')
# ('massinha', 'dinossauros') ('dinossauros', 'aprenda')
# ('tapa', 'popote') ('popote', 'dibujos')
# ('коллекция', 'даша') ('даша', 'людоед')
# ('vehículos', 'ayudantes') ('ayudantes', 'estreno')
# ('الحلقة', 'مقاطعة') ('مقاطعة', 'الكلام')
# ('esponja', 'dibujos') ('pelota', 'esponja')
# ('aspiradora', 'o') ('limpia', 'con')
# ('aspiradora', 'o') ('más', 'limpia')
# ('mug', 'maybe') ('maybe', 'bloom')
# ('com', 'lápis') ('elástico', 'e')
# ('cartoons', 'cartoonsforkids') ('educationalgames', 'cartoons')
# ('cartoons', 'cartoonsforkids') ('rocksongforkids', 'music')
# ('cartoons', 'cartoonsforkids') ('music', 'educationalgames')
# ('cartoons', 'cartoonsforkids') ('nurseryrhymes', 'rocksongforkids')
# ('أتقن', 'عملك') ('عملك', 'تحقق')
# ('أتقن', 'عملك') ('الحلقة', 'أتقن')
# ('أتقن', 'عملك') ('تحقق', 'أملك')
# ('bebês', 'animazinhos') ('animazinhos', 'massinha')
# ('cars', 'helpers') ('helpers', 'best')
# ('crea', 'juega') ('esp', 'crea')
# ('counting', 'sheep') ('sleeping', 'counting')
# ('creativas', 'dibujos') ('habilidades', 'creativas')
# ('小动物们', '小猫') ('动画片', '小动物们')
# ('caballos', 'aves') ('aves', 'pilotos')
# ('playing', 'new') ('drawing', 'playing')
# ('rey', 'los') ('líder', 'música')
# ('rey', 'los') ('para', 'descubrir')
# ('educationalgames', 'cartoons') ('rocksongforkids', 'music')
# ('educationalgames', 'cartoons') ('music', 'educationalgames')
# ('educationalgames', 'cartoons') ('nurseryrhymes', 'rocksongforkids')
# ('drop', 'pick') ('pick', 'up')
# ('الأصدقاء', 'نوافذ') ('نوافذ', 'السعادة')
# ('vacuum', 'abc') ('karaoke', 'vacuum')
# ('badminton', 'linterna') ('linterna', 'dibujos')
# ('haciendo', 'felices') ('felices', 'los')
# ('عملك', 'تحقق') ('الحلقة', 'أتقن')
# ('عملك', 'تحقق') ('تحقق', 'أملك')
# ('badminton', 'adventure') ('kids', 'badminton')
# ('special', 'eid') ('حلقة', 'عيد')
# ('special', 'eid') ('أحلى', 'حلقة')
# ('special', 'eid') ('cow', 'مفاجأة')
# ('special', 'eid') ('لعائلة', 'أبريكوت')
# ('kids', 'newcartoon') ('how', 'amazing')
# ('kids', 'newcartoon') ('its', 'shell')
# ('kids', 'newcartoon') ('amazing', 'kids')
# ('القطع', 'المئة') ('أحجية', 'القطع')
# ('fenómenos', 'naturales') ('los', 'fenómenos')
# ('fenómenos', 'naturales') ('clima', 'los')
# ('music', 'time') ('learn', 'instruments')
# ('preguntar', 'adivinar') ('adivinar', 'dibujos')
# ('kittens', 'fly') ('can', 'kittens')
# ('locations', 'new') ('weather', 'locations')
# ('حمل', 'الأسرار') ('حمل', 'الأثقال')
# ('حمل', 'الأسرار') ('الأسرار', 'أثقل')
# ('حمل', 'الأسرار') ('الحلقة', 'حمل')
# ('حمل', 'الأسرار') ('من', 'حمل')
# ('artistas', 'elige') ('niños', 'pincel')
# ('artistas', 'elige') ('pincel', 'aventuras')
# ('artistas', 'elige') ('aventuras', 'creativas')
# ('artistas', 'elige') ('tu', 'pincel')
# ('bebês', 'animais') ('filhotes', 'fofinhos')
# ('bebês', 'animais') ('mais', 'adoráveis')
# ('bebês', 'animais') ('massinha', 'filhotes')
# ('bebês', 'animais') ('os', 'bebês')
# ('bebês', 'animais') ('fofinhos', 'os')
# ('bebês', 'animais') ('adoráveis', 'do')
# ('record', 'race') ('carrot', 'record')
# ('record', 'race') ('world', 'carrot')
# ('strings', 'instruments') ('kids', 'bowed')
# ('make', 'play') ('doh', 'animals')
# ('تعليمي', 'للاطفال') ('مسلسل', 'تعليمي')
# ('plot', 'abc') ('karaoke', 'plot')
# ('على', 'الأذى') ('احصل', 'على')
# ('espectáculos', 'dibujos') ('teatro', 'espectáculos')
# ('música', 'viajes') ('espaciales', 'para')
# ('mágicas', 'para') ('casitas', 'mágicas')
# ('mágicas', 'para') ('animales', 'aventuras')
# ('ti', 'new') ('games', 'baby')
# ('juegos', 're') ('re', 'dibujos')
# ('maleta', 'música') ('hora', 'empacar')
# ('maleta', 'música') ('empacar', 'juega')
# ('maleta', 'música') ('esp', 'hora')
# ('للأطفال', 'كرم') ('الضيافة', 'orange')
# ('únete', 'al') ('español', 'risas')
# ('únete', 'al') ('desafío', 'bádminton')
# ('únete', 'al') ('bádminton', 'los')
# ('únete', 'al') ('juego', 'aventuras')
# ('únete', 'al') ('aventuras', 'únete')
# ('fafs', 'doing') ('doing', 'nursery')
# ('highres', 'fun') ('pot', 'highres')
# ('العد', 'من') ('تعلم', 'العد')
# ('العد', 'من') ('الى', 'الصلصال')
# ('العد', 'من') ('الارقام', 'كرتون')
# ('español', 'risas') ('desafío', 'bádminton')
# ('español', 'risas') ('bádminton', 'los')
# ('español', 'risas') ('juego', 'aventuras')
# ('español', 'risas') ('aventuras', 'únete')
# ('español', 'música') ('esp', 'pintar')
# ('español', 'música') ('pintar', 'con')
# ('تعلم', 'العد') ('الى', 'الصلصال')
# ('تعلم', 'العد') ('الارقام', 'كرتون')
# ('lo', 'ancho') ('ancho', 'dibujos')
# ('lo', 'ancho') ('largo', 'lo')
# ('yourselves', 'home') ('make', 'yourselves')
# ('حمل', 'الأثقال') ('الأسرار', 'أثقل')
# ('حمل', 'الأثقال') ('الحلقة', 'حمل')
# ('حمل', 'الأثقال') ('من', 'حمل')
# ('big', 'toys') ('toys', 'nursery')
# ('الحلقة', 'كنوز') ('كنوز', 'الخريف')
# ('nieve', 'nuevos') ('los', 'muñecos')
# ('ready', 'get') ('set', 'goooo')
# ('ready', 'get') ('goooo', 'animation')
# ('الأسرار', 'أثقل') ('الحلقة', 'حمل')
# ('الأسرار', 'أثقل') ('من', 'حمل')
# ('para', 'mascotas') ('talentos', 'para')
# ('transport', 'traffic') ('learn', 'transport')
# ('transport', 'traffic') ('traffic', 'kids')
# ('transport', 'traffic') ('cars', 'trains')
# ('transport', 'traffic') ('trains', 'planes')
# ('niños', 'pincel') ('pincel', 'aventuras')
# ('niños', 'pincel') ('aventuras', 'creativas')
# ('niños', 'pincel') ('tu', 'pincel')
# ('best', 'ideas') ('ideas', 'games')
# ('horsies', 'learning') ('animals', 'horsies')
# ('percussion', 'best') ('instruments', 'percussion')
# ('great', 'pretender') ('pretender', 'learning')
# ('great', 'pretender') ('truth', 'orange')
# ('great', 'pretender') ('tell', 'truth')
# ('babies', 'new') ('games', 'babies')
# ('adventure', 'educational') ('plate', 'adventure')
# ('karaoke', 'umbrella') ('umbrella', 'abc')
# ('بالمراسلة', 'كرتون') ('اصدقاء', 'بالمراسلة')
# ('set', 'goooo') ('goooo', 'animation')
# ('doh', 'cartoon') ('count', 'play')
# ('الحلقة', 'حمل') ('من', 'حمل')
# ('desafío', 'bádminton') ('bádminton', 'los')
# ('desafío', 'bádminton') ('juego', 'aventuras')
# ('desafío', 'bádminton') ('aventuras', 'únete')
# ('peligro', 'dibujos') ('flor', 'está')
# ('peligro', 'dibujos') ('una', 'flor')
# ('sorprendentes', 'música') ('música', 'en')
# ('passenger', 'educational') ('vehicles', 'passenger')
# ('filhotes', 'fofinhos') ('mais', 'adoráveis')
# ('filhotes', 'fofinhos') ('massinha', 'filhotes')
# ('filhotes', 'fofinhos') ('os', 'bebês')
# ('filhotes', 'fofinhos') ('fofinhos', 'os')
# ('filhotes', 'fofinhos') ('adoráveis', 'do')
# ('carrot', 'record') ('world', 'carrot')
# ('recordar', 'dibujos') ('olvidar', 'recordar')
# ('me', 'soviet') ('soviet', 'cartoons')
# ('ideas', 'para') ('para', 'juegos')
# ('pincel', 'aventuras') ('aventuras', 'creativas')
# ('pincel', 'aventuras') ('tu', 'pincel')
# ('طريقة', 'للوصول') ('للوصول', 'بدون')
# ('طريقة', 'للوصول') ('بدون', 'خريطة')
# ('gancho', 'dibujos') ('escobilla', 'gancho')
# ('kittens', 'love') ('what', 'about')
# ('amistad', 'compromiso') ('compromiso', 'dibujos')
# ('how', 'amazing') ('its', 'shell')
# ('how', 'amazing') ('amazing', 'kids')
# ('pretender', 'learning') ('truth', 'orange')
# ('pretender', 'learning') ('tell', 'truth')
# ('hoy', 'dibujos') ('animal', 'serán')
# ('حلقة', 'عيد') ('أحلى', 'حلقة')
# ('حلقة', 'عيد') ('cow', 'مفاجأة')
# ('حلقة', 'عيد') ('لعائلة', 'أبريكوت')
# ('ازرع', 'خيرا') ('تحصد', 'شرا')
# ('ازرع', 'خيرا') ('الحلقة', 'ازرع')
# ('الى', 'الصلصال') ('الارقام', 'كرتون')
# ('la', 'cacerola') ('canción', 'la')
# ('la', 'cacerola') ('esp', 'descubre')
# ('recorde', 'cenoura') ('laranja', 'recorde')
# ('kidssong', 'newcartoon') ('cartoonsforkids', 'rocksongforkids')
# ('kidssong', 'newcartoon') ('educationalgames', 'cartoonsforkids')
# ('kidssong', 'newcartoon') ('rocksongforkids', 'nurseryrhymes')
# ('hot', 'summer') ('fan', 'cartoon')
# ('hot', 'summer') ('adventures', 'fan')
# ('fan', 'cartoon') ('adventures', 'fan')
# ('flor', 'está') ('una', 'flor')
# ('everything', 'about') ('learn', 'everything')
# ('everything', 'about') ('about', 'cats')
# ('everything', 'about') ('videos', 'meow')
# ('musipachescómo', 'usar') ('series', 'musipachescómo')
# ('abanico', 'dibujos') ('pincel', 'abanico')
# ('los', 'fenómenos') ('clima', 'los')
# ('musicales', 'estreno') ('instrumentos', 'musicales')
# ('world', 'guests') ('wild', 'orange')
# ('umbrella', 'cloudy') ('cloudy', 'friend')
# ('educationalgames', 'nurseryrythmes') ('kids', 'educationalgames')
# ('educationalgames', 'nurseryrythmes') ('nurseryrythmes', 'kidssong')
# ('ray', 'dibujos') ('juegos', 'ray')
# ('canción', 'la') ('esp', 'descubre')
# ('limpia', 'con') ('más', 'limpia')
# ('karaoke', 'fan') ('fan', 'abc')
# ('líder', 'música') ('para', 'descubrir')
# ('brinca', 'desenhos') ('e', 'brinca')
# ('ninguno', 'dibujos') ('todos', 'ninguno')
# ('cow', 'كابتن') ('كابتن', 'زوه')
# ('cow', 'كابتن') ('زوه', 'عائلة')
# ('vehículos', 'mágicos') ('mágicos', 'en')
# ('mais', 'adoráveis') ('massinha', 'filhotes')
# ('mais', 'adoráveis') ('os', 'bebês')
# ('mais', 'adoráveis') ('fofinhos', 'os')
# ('mais', 'adoráveis') ('adoráveis', 'do')
# ('animation', 'orangemoocow') ('متحركة', 'animation')
# ('animation', 'orangemoocow') ('orangemoocow', 'kids')
# ('cartoonsforkids', 'rocksongforkids') ('educationalgames', 'cartoonsforkids')
# ('cartoonsforkids', 'rocksongforkids') ('rocksongforkids', 'nurseryrhymes')
# ('going', 'up') ('up', 'going')
# ('ruidoso', 'silencioso') ('silencioso', 'dibujos')
# ('pilots', 'best') ('cars', 'pilots')
# ('mapaches', 'dibujos') ('con', 'mapaches')
# ('في', 'الخدعة') ('الخدعة', 'منفعة')
# ('learn', 'everything') ('about', 'cats')
# ('learn', 'everything') ('videos', 'meow')
# ('crown', 'abc') ('karaoke', 'crown')
# ('التدريب', 'الرياضي') ('موعد', 'التدريب')
# ('misteriosa', 'nuevos') ('nube', 'misteriosa')
# ('misteriosa', 'nuevos') ('la', 'nube')
# ('hora', 'empacar') ('empacar', 'juega')
# ('hora', 'empacar') ('esp', 'hora')
# ('educationalgames', 'cartoonsforkids') ('rocksongforkids', 'nurseryrhymes')
# ('الحلقة', 'أتقن') ('تحقق', 'أملك')
# ('learn', 'transport') ('traffic', 'kids')
# ('learn', 'transport') ('cars', 'trains')
# ('learn', 'transport') ('trains', 'planes')
# ('كابتن', 'زوه') ('زوه', 'عائلة')
# ('truth', 'orange') ('tell', 'truth')
# ('casitas', 'mágicas') ('animales', 'aventuras')
# ('massinha', 'filhotes') ('os', 'bebês')
# ('massinha', 'filhotes') ('fofinhos', 'os')
# ('massinha', 'filhotes') ('adoráveis', 'do')
# ('little', 'numbers') ('numbers', 'learning')
# ('rocksongforkids', 'music') ('music', 'educationalgames')
# ('rocksongforkids', 'music') ('nurseryrhymes', 'rocksongforkids')
# ('about', 'cats') ('videos', 'meow')
# ('nube', 'misteriosa') ('la', 'nube')
# ('its', 'shell') ('amazing', 'kids')
# ('تحصد', 'شرا') ('الحلقة', 'ازرع')
# ('con', 'cuerdas') ('cuerdas', 'teclas')
# ('للوصول', 'بدون') ('بدون', 'خريطة')
# ('متحركة', 'animation') ('orangemoocow', 'kids')
# ('kids', 'educationalgames') ('nurseryrythmes', 'kidssong')
# ('aventuras', 'creativas') ('tu', 'pincel')
# ('fun', 'counting') ('counting', 'live')
# ('os', 'bebês') ('fofinhos', 'os')
# ('os', 'bebês') ('adoráveis', 'do')
# ('music', 'educationalgames') ('nurseryrhymes', 'rocksongforkids')
# ('bádminton', 'los') ('juego', 'aventuras')
# ('bádminton', 'los') ('aventuras', 'únete')
# ('esp', 'pintar') ('pintar', 'con')
# ('juegos', 'deporte') ('deporte', 'dibujos')
# ('fofinhos', 'os') ('adoráveis', 'do')
# ('ubicaciones', 'dibujos') ('las', 'ubicaciones')
# ('juego', 'aventuras') ('aventuras', 'únete')
# ('greedy', 'infection') ('mug', 'greedy')
# ('الحلقة', 'احتفالات') ('احتفالات', 'لا')
# ('blum', 'great') ('mug', 'blum')
# ('calm', 'down') ('mug', 'calm')
# ('calm', 'down') ('down', 'save')
# ('أحلى', 'حلقة') ('cow', 'مفاجأة')
# ('أحلى', 'حلقة') ('لعائلة', 'أبريكوت')
# ('الحلقة', 'معا') ('معا', 'بلا')
# ('below', 'above') ('above', 'new')
# ('empacar', 'juega') ('esp', 'hora')
# ('cow', 'مفاجأة') ('لعائلة', 'أبريكوت')
# ('traffic', 'kids') ('cars', 'trains')
# ('traffic', 'kids') ('trains', 'planes')
# ('contar', 'número') ('número', 'videos')
# ('vamos', 'aprender') ('contar', 'desenho')
# ('maleta', 'corona') ('corona', 'dibujos')
# ('ancho', 'dibujos') ('largo', 'lo')
# ('cars', 'trains') ('trains', 'planes')
# ('غنائي', 'هادف') ('للبنات', 'الحان')
# ('short', 'long') ('long', 'nursery')
# ('botones', 'con') ('fiesta', 'botones')
# ('mug', 'calm') ('down', 'save')

# %%
bigrams_final_set = bigrams_final_set - set(to_remove)
print(len(bigrams_final_set))
# Out:
# 529

# %%
#bigrams_final_set
#unigrams_final_set

# %%
with open("bigrams_final_set.pkl", 'wb') as file:
    # Serialize and write the set to the file
    pickle.dump(bigrams_final_set, file)
file.close()

# %%
with open("unigrams_final_set.pkl", 'wb') as file:
    # Serialize and write the set to the file
    pickle.dump(unigrams_final_set, file)
file.close()

# %% [markdown]
# # Combine uni- and bi-grams

# %%
reels_plus =  df_sql[df_sql.product_id != ''].copy()

# %%
reels_plus['ch2_bigrams'] = reels_plus['bigrams'].apply(get_intersect_ch, args=(bigrams_set,)) 
reels_plus['sel_bigrams'] = reels_plus['bigrams'].apply(get_intersect, args=(bigrams_set,)) 
reels_multi = reels_plus[reels_plus.ch2_bigrams >  1].copy() # was >1
reels_multi = reels_multi[['yt_reel_id', 'bigrams', 'sel_bigrams', 'ch2_bigrams']]

# %%
bigram2reels = {}
for bigram in bigrams_final_set:
    df_temp = reels_multi[reels_multi['bigrams'].apply(lambda x: isinstance(x, list) and bigram in x)]
    bigram2reels[bigram] = set(df_temp.yt_reel_id.to_list())

# %%
df_bigram2reels = pd.DataFrame( [(k, list(v)) for k, v in bigram2reels.items()], columns=['bigram', 'id'])

# %%
reels_plus['ch2_unigrams'] = reels_plus['tokens'].apply(get_intersect_ch, args=(unigrams_set,)) 
reels_multi = reels_plus[reels_plus.ch2_unigrams >  1].copy() # was >1
reels_multi['unigrams'] = reels_plus['tokens'].apply(get_intersect, args=(unigrams_set,)) 
reels_multi = reels_multi[['yt_reel_id', 'tokens', 'unigrams', 'ch2_unigrams']]

# %%
unigram2reels = {}
for unigram in unigrams_final_set:
    df_temp = reels_multi[reels_multi['tokens'].apply(lambda x: isinstance(x, list) and unigram in x)]
    unigram2reels[unigram] = set(df_temp.yt_reel_id.to_list())

# %%
df_unigram2reels = pd.DataFrame( [(k, list(v)) for k, v in unigram2reels.items()], columns=['unigram', 'id'])
df_unigram2reels.columns = ['unigramm', 'ids']

# %%
df_unigram2reels.columns = ['x_grams', 'ids']
df_bigram2reels.columns = ['x_grams', 'ids']

# %%
df_grams2reels = pd.concat([df_unigram2reels,df_bigram2reels])

# %%
grams_set = set(df_grams2reels['x_grams'].to_list())

# %%
to_remove = []
for i in range(len(grams_set)):
    print(i, end = ' - ')
    bi_1 = list(grams_set)[i]
    for j in range(i+1,len(grams_set)):
        bi_2 =  list(grams_set)[j]
        a = set(df_grams2reels[df_grams2reels.x_grams == bi_1].ids.to_list()[0])
        b = set(df_grams2reels[df_grams2reels.x_grams == bi_2].ids.to_list()[0])
        if(a >= b):
            print(bi_1, bi_2)
            to_remove.append(bi_2)
# Out:
# الخمول ('نوم', 'بهدوء')
# deeds ('journal', 'orange')
# plastideas ('jugando', 'transformándote')
# plastideas ('las', 'plantas')
# plastideas ('qué', 'animal')
# plastideas ('guauguau', 'aprende')
# plastideas ('mágica', 'con')
# plastideas ('acción', 'para')
# plastideas ('instrumentos', 'sorprendentes')
# plastideas ('vehículos', 'ayudantes')
# plastideas ('musicales', 'estreno')
# الراكون ('كرتون', 'غنائي')
# الراكون ('القراصنة', 'كرتون')
# الراكون ('ندف', 'الثلج')
# الراكون ('الفوانيس', 'كرتون')
# الراكون ('الحقيبة', 'كرتون')
# الراكون ('المكنسة', 'الكهربائية')
# الراكون ('كيدو', 'الحان')
# الراكون ('الريشة', 'الطائرة')
# الراكون ('المظلة', 'كرتون')
# الراكون ('الخشخيشة', 'كرتون')
# الراكون ('التاج', 'كرتون')
# الراكون ('للأطفال', 'الحان')
# الراكون ('الفرشاة', 'كرتون')
# الراكون ('عصا', 'الطبل')
# الراكون ('الازرار', 'كرتون')
# musipaches ('idéntico', 'diferente')
# musipaches ('naturales', 'dibujos')
# musipaches ('columpio', 'dibujos')
# musipaches ('popote', 'peine')
# musipaches ('redondos', 'dibujos')
# musipaches ('ligas', 'dibujos')
# musipaches ('libreta', 'dibujos')
# musipaches ('silbato', 'baúl')
# musipaches ('frente', 'dibujos')
# musipaches ('ligero', 'pesado')
# musipaches ('reducido', 'espacioso')
# musipaches ('pegatina', 'trapeador')
# musipaches ('cancioneseducativas', 'niños')
# musipaches ('campanas', 'dibujos')
# musipaches ('infantiles', 'educativos')
# musipaches ('aspiradora', 'dibujos')
# musipaches ('subir', 'bajar')
# musipaches ('juegos', 'activos')
# musipaches ('tapa', 'popote')
# musipaches ('esponja', 'dibujos')
# musipaches ('crea', 'juega')
# musipaches ('creativas', 'dibujos')
# musipaches ('tomar', 'devolver')
# musipaches ('niños', 'kids')
# musipaches ('badminton', 'linterna')
# musipaches ('sombrero', 'mágico')
# musipaches ('educativos', 'cancioneseducativas')
# musipaches ('preguntar', 'adivinar')
# musipaches ('copos', 'nieve')
# musipaches ('artistas', 'elige')
# musipaches ('espectáculos', 'dibujos')
# musipaches ('recordar', 'dibujos')
# musipaches ('gancho', 'dibujos')
# musipaches ('amistad', 'compromiso')
# musipaches ('la', 'cacerola')
# musipaches ('abanico', 'dibujos')
# musipaches ('niños', 'cancioneseducativas')
# musipaches ('ninguno', 'dibujos')
# musipaches ('solos', 'juntos')
# musipaches ('interferir', 'ayudar')
# musipaches ('llave', 'puerta')
# musipaches ('esp', 'jugar')
# musipaches ('ruidoso', 'silencioso')
# musipaches ('bastones', 'hockey')
# musipaches ('mapaches', 'dibujos')
# musipaches ('rápido', 'lento')
# musipaches ('los', 'magos')
# musipaches ('objetos', 'dibujos')
# musipaches ('cancioneseducativas', 'musica')
# musipaches ('sucio', 'limpio')
# musipaches ('activos', 'dibujos')
# musipaches ('niños', 'infantiles')
# musipaches ('la', 'baqueta')
# musipaches ('botones', 'con')
# musipaches ('la', 'pala')
# musipaches ('kids', 'educativos')
# chirp ('la', 'colmena')
# ('مجموعة', 'الأذى') سأمسك
# ('secretos', 'del') valle
# rockoons ('scale', 'abc')
# rockoons ('buttons', 'abc')
# rockoons ('now', 'later')
# rockoons ('drumstick', 'abc')
# rockoons ('friends', 'сartoons')
# rockoons ('kids', 'nurseryrythmes')
# rockoons ('suitcase', 'abc')
# rockoons ('hat', 'abc')
# rockoons ('cartoons', 'cartoonsforkids')
# rockoons ('messy', 'tidy')
# rockoons ('vacuum', 'abc')
# rockoons ('locations', 'new')
# rockoons ('help', 'hinder')
# rockoons ('plot', 'abc')
# rockoons ('can', 'cannot')
# rockoons ('fafs', 'doing')
# rockoons ('highres', 'fun')
# rockoons ('quickly', 'slowly')
# rockoons ('karaoke', 'umbrella')
# rockoons ('cozy', 'spacious')
# rockoons ('push', 'pull')
# rockoons ('kidssong', 'newcartoon')
# rockoons ('key', 'door')
# rockoons ('educationalgames', 'nurseryrythmes')
# rockoons ('karaoke', 'fan')
# rockoons ('speak', 'silent')
# rockoons ('crown', 'abc')
# rockoons ('elastic', 'band')
# rockoons ('enter', 'exit')
# rockoons ('active', 'games')
# rockoons ('songsforkids', 'nurseryrhymes')
# rockoons ('narrow', 'wide')
# rockoons ('fragile', 'sturdy')
# animaizinhos ('animais', 'mais')
# infancia ('niños', 'cancioneseducativas')
# infancia ('kids', 'educativos')
# moo ('كاريكاتير', 'للأطفال')
# 彩泥行动 ('动画片', '我们在学习数数')
# monsikids ('greedy', 'infection')
# monsikids ('blum', 'great')
# moocow ('yourselves', 'home')
# claymotions ('horsies', 'learning')
# claymotions ('percussion', 'best')
# claymotions ('count', 'legs')
# oomka ('english', 'great')

# %%
print(len(grams_set))
print(len(set(to_remove)))
# Out:
# 568
# 128

# %%
final_grams_set = (grams_set - set(to_remove))
print(len(final_grams_set))
# Out:
# 440

# %%
with open("final_grams_set.pkl", 'wb') as file:
    # Serialize and write the set to the file
    pickle.dump(final_grams_set, file)
file.close()

# %%
final_grams_set
# Out:
# {('4super', 'toonstv'),
#  ('about', 'family'),
#  ('above', 'below'),
#  ('action', 'packed'),
#  ('activities', 'new'),
#  ('adventure', 'educational'),
#  ('adventure', 'music'),
#  ('al', 'desafío'),
#  ('almuerzo', 'saludable'),
#  ('alone', 'together'),
#  ('along', 'across'),
#  ('always', 'never'),
#  ('amigos', 'dasha'),
#  ('amigos', 'do'),
#  ('amigos', 'grey'),
#  ('animada', 'educativa'),
#  ('animados', 'cancioneseducativas'),
#  ('animados', 'niños'),
#  ('animal', 'learn'),
#  ('animales', 'cuántas'),
#  ('animales', 'guauguau'),
#  ('animales', 'quién'),
#  ('animals', 'cartoon'),
#  ('animals', 'how'),
#  ('animals', 'kittens'),
#  ('animals', 'learn'),
#  ('animals', 'teeth'),
#  ('animals', 'who'),
#  ('animals', 'whos'),
#  ('animals', 'woofwoof'),
#  ('antifaz', 'dibujos'),
#  ('aprenda', 'e'),
#  ('aprenda', 'os'),
#  ('apresurar', 'dibujos'),
#  ('arctic', 'adventure'),
#  ('arriba', 'abajo'),
#  ('arte', 'dibujos'),
#  ('atrapar', 'dibujos'),
#  ('aventuras', 'casitas'),
#  ('ayudando', 'amigos'),
#  ('babies', 'new'),
#  ('baby', 'ti'),
#  ('balde', 'músicas'),
#  ('battle', 'best'),
#  ('bebês', 'animazinhos'),
#  ('before', 'behind'),
#  ('beging', 'end'),
#  ('below', 'above'),
#  ('best', 'ideas'),
#  ('big', 'toys'),
#  ('biggest', 'animal'),
#  ('birdies', 'learning'),
#  ('botones', 'maleta'),
#  ('bowed', 'strings'),
#  ('brasil', 'orange'),
#  ('break', 'fake'),
#  ('brincar', 'aprender'),
#  ('bádminton', 'con'),
#  ('cacerola', 'dibujos'),
#  ('campamento', 'nuevos'),
#  ('canción', 'maleta'),
#  ('caracol', 'súper'),
#  ('caracola', 'almohada'),
#  ('caracola', 'dibujos'),
#  ('cars', 'helpers'),
#  ('carta', 'nuevos'),
#  ('cartoon', 'golden'),
#  ('cartoons', 'can'),
#  ('cartoons', 'kittens'),
#  ('cartoons', 'orange'),
#  ('cartoons', 'play'),
#  ('cenoura', 'aprenda'),
#  ('chasing', 'running'),
#  ('clay', 'educational'),
#  ('clima', 'las'),
#  ('clothes', 'invisible'),
#  ('cold', 'bit'),
#  ('colección', 'grande'),
#  ('con', 'plastilina'),
#  ('concurso', 'talentos'),
#  ('contar', 'número'),
#  ('contar', 'números'),
#  ('cosas', 'nuevas'),
#  ('count', 'super'),
#  ('cow', 'compilation'),
#  ('cross', 'kind'),
#  ('dalia', 'ogro'),
#  ('defend', 'yourself'),
#  ('desert', 'laziness'),
#  ('different', 'same'),
#  ('dinosaurs', 'learn'),
#  ('dishes', 'food'),
#  ('dishes', 'new'),
#  ('doh', 'cartoon'),
#  ('doh', 'learning'),
#  ('drop', 'pick'),
#  ('easy', 'count'),
#  ('educativos', 'dibujos'),
#  ('elástica', 'desenho'),
#  ('empathy', 'emotions'),
#  ('empatía', 'emociones'),
#  ('encuentro', 'despedida'),
#  ('enojado', 'amable'),
#  ('escondite', 'busca'),
#  ('esp', 'rey'),
#  ('español', 'ay'),
#  ('español', 'música'),
#  ('esperando', 'la'),
#  ('esponja', 'escobilla'),
#  ('estreia', 'novo'),
#  ('even', 'numbers'),
#  ('everyone', 'no'),
#  ('fan', 'musical'),
#  ('faster', 'learn'),
#  ('favoritas', 'dibujos'),
#  ('favorite', 'games'),
#  ('fin', 'del'),
#  ('first', 'last'),
#  ('food', 'kitchen'),
#  ('fools', 'gold'),
#  ('free', 'time'),
#  ('friends', 'comedy'),
#  ('friendship', 'compromise'),
#  ('fuerte', 'estreno'),
#  ('fun', 'catchy'),
#  ('fun', 'counting'),
#  ('funny', 'animal'),
#  ('games', 'ball'),
#  ('games', 'beach'),
#  ('games', 'boys'),
#  ('games', 'friends'),
#  ('games', 'nursery'),
#  ('games', 'theatre'),
#  ('gancho', 'imán'),
#  ('gatitos', 'estreno'),
#  ('get', 'set'),
#  ('go', 'nursery'),
#  ('going', 'down'),
#  ('gran', 'historia'),
#  ('gran', 'ludel'),
#  ('guerra', 'los'),
#  ('guess', 'animal'),
#  ('guess', 'riddle'),
#  ('guests', 'gone'),
#  ('haciendo', 'felices'),
#  ('here', 'there'),
#  ('high', 'low'),
#  ('hobby', 'michael'),
#  ('hockey', 'stick'),
#  ('honey', 'hills'),
#  ('hot', 'summer'),
#  ('hula', 'hula'),
#  ('ideas', 'para'),
#  ('ill', 'get'),
#  ('im', 'house'),
#  ('infantil', 'los'),
#  ('infantiles', 'canciones'),
#  ('infantiles', 'niños'),
#  ('inside', 'outside'),
#  ('instruments', 'kids'),
#  ('izquierda', 'derecha'),
#  ('jalar', 'empujar'),
#  ('juegos', 'amigos'),
#  ('juegos', 'brillantes'),
#  ('juegos', 'creativos'),
#  ('juegos', 'deporte'),
#  ('juegos', 'deportivos'),
#  ('juegos', 'fav'),
#  ('juegos', 'favoritos'),
#  ('juegos', 'para'),
#  ('juegos', 're'),
#  ('juguetes', 'bonitos'),
#  ('karaoke', 'lanterns'),
#  ('kids', 'captain'),
#  ('kids', 'conductors'),
#  ('kids', 'keyboard'),
#  ('kids', 'orange'),
#  ('kids', 'singing'),
#  ('kids', 'sport'),
#  ('kids', 'unusual'),
#  ('kittens', 'learn'),
#  ('laranja', 'presente'),
#  ('laranja', 'sintamse'),
#  ('laranja', 'uma'),
#  ('las', 'vacas'),
#  ('learn', 'tell'),
#  ('learning', 'play'),
#  ('learning', 'rules'),
#  ('learning', 'super'),
#  ('letter', 'santa'),
#  ('libre', 'dibujos'),
#  ('ligas', 'pinzas'),
#  ('linterna', 'pincel'),
#  ('lleno', 'vacío'),
#  ('lo', 'largo'),
#  ('lost', 'notebook'),
#  ('lot', 'bit'),
#  ('loud', 'quiet'),
#  ('lápis', 'elástico'),
#  ('lápis', 'músicas'),
#  ('make', 'play'),
#  ('maleta', 'corona'),
#  ('mania', 'عائلة'),
#  ('many', 'legs'),
#  ('many', 'raisins'),
#  ('mapaches', 'episodios'),
#  ('massinha', 'au'),
#  ('massinha', 'dinossauros'),
#  ('massinha', 'gatinhos'),
#  ('me', 'animal'),
#  ('me', 'soviet'),
#  ('meet', 'see'),
#  ('meow', 'lets'),
#  ('migratory', 'birds'),
#  ('mine', 'yours'),
#  ('minute', 'cartoon'),
#  ('missing', 'pie'),
#  ('missing', 'tree'),
#  ('misteriosa', 'nuevos'),
#  ('mood', 'adventures'),
#  ('mug', 'black'),
#  ('mug', 'clouds'),
#  ('mug', 'invisible'),
#  ('mug', 'maybe'),
#  ('mug', 'pirate'),
#  ('mug', 'sleeping'),
#  ('musical', 'cartoons'),
#  ('musipachescómo', 'usar'),
#  ('música', 'con'),
#  ('new', 'caroons'),
#  ('new', 'games'),
#  ('new', 'old'),
#  ('new', 'record'),
#  ('new', 'things'),
#  ('newcartoon', 'nurseryrhymes'),
#  ('niños', 'animados'),
#  ('not', 'ski'),
#  ('novo', 'recorde'),
#  ('nueva', 'colección'),
#  ('nuevas', 'historias'),
#  ('nuevo', 'viejo'),
#  ('nuevos', 'juegos'),
#  ('number', 'learn'),
#  ('numbers', 'cartoon'),
#  ('numbers', 'counting'),
#  ('numbers', 'learn'),
#  ('numbers', 'super'),
#  ('número', 'um'),
#  ('números', 'mágicos'),
#  ('números', 'plastilina'),
#  ('o', 'balanço'),
#  ('o', 'elástico'),
#  ('o', 'juguete'),
#  ('objects', 'new'),
#  ('objetos', 'del'),
#  ('odd', 'numbers'),
#  ('one', 'two'),
#  ('orden', 'desorden'),
#  ('paint', 'brushes'),
#  ('paintbrushes', 'abc'),
#  ('para', 'amigos'),
#  ('part', 'whole'),
#  ('parte', 'entero'),
#  ('passenger', 'educational'),
#  ('peine', 'ruedas'),
#  ('peligro', 'dibujos'),
#  ('pequena', 'aranha'),
#  ('peques', 'número'),
#  ('perder', 'encontrar'),
#  ('performances', 'new'),
#  ('peter', 'wolf'),
#  ('pilotos', 'aventuras'),
#  ('pilots', 'best'),
#  ('pinzas', 'plastilina'),
#  ('piramide', 'dibujos'),
#  ('pirata', 'con'),
#  ('pirata', 'los'),
#  ('pirate', 'school'),
#  ('pirates', 'abc'),
#  ('planes', 'learn'),
#  ('plato', 'pegatina'),
#  ('platos', 'comida'),
#  ('play', 'dance'),
#  ('playing', 'new'),
#  ('plucked', 'string'),
#  ('preguiça', 'terrível'),
#  ('preguiça', 'toons'),
#  ('quiet', 'loud'),
#  ('race', 'orange'),
#  ('race', 'say'),
#  ('rattle', 'sing'),
#  ('ray', 'dibujos'),
#  ('remember', 'new'),
#  ('resolviendo', 'problemas'),
#  ('roccoons', 'musical'),
#  ('ropa', 'para'),
#  ('row', 'numbers'),
#  ('save', 'world'),
#  ('scrappy', 'new'),
#  ('secretos', 'del'),
#  ('short', 'long'),
#  ('siempre', 'nunca'),
#  ('siete', 'mapaches'),
#  ('snowflakes', 'childrens'),
#  ('soccer', 'math'),
#  ('solo', 'video'),
#  ('spa', 'day'),
#  ('spring', 'miracle'),
#  ('stacking', 'toy'),
#  ('strong', 'character'),
#  ('sympathy', 'nursery'),
#  ('taco', 'hóquei'),
#  ('take', 'give'),
#  ('teatro', 'dibujos'),
#  ('throwing', 'catching'),
#  ('timid', 'brave'),
#  ('tirar', 'levantar'),
#  ('toddler', 'learning'),
#  ('toons', 'orange'),
#  ('toys', 'new'),
#  ('trouble', 'nursery'),
#  ('trouble', 'timmy'),
#  ('tímido', 'valiente'),
#  ('umbrella', 'cloudy'),
#  ('underwater', 'plants'),
#  ('valuable', 'cargo'),
#  ('vamos', 'aprender'),
#  ('vaso', 'dibujos'),
#  ('vaso', 'plato'),
#  ('vehicles', 'helpers'),
#  ('vehicles', 'passengers'),
#  ('vehículos', 'dinosaurios'),
#  ('viajes', 'aventuras'),
#  ('videos', 'lantern'),
#  ('wait', 'rush'),
#  ('walk', 'stand'),
#  ('where', 'wolf'),
#  ('who', 'biggest'),
#  ('who', 'stronger'),
#  ('whos', 'faster'),
#  ('whos', 'fastest'),
#  ('wind', 'instruments'),
#  ('winter', 'game'),
#  ('woof', 'super'),
#  ('world', 'game'),
#  ('yo', 'dibujos'),
#  ('yo', 'tesoros'),
#  ('you', 'orange'),
#  ('коллекция', 'даша'),
#  ('коллекция', 'умка'),
#  ('лентяйка', 'василиса'),
#  ('أتقن', 'عملك'),
#  ('أثقل', 'من'),
#  ('أغاني', 'أطفال'),
#  ('اكتشاف', 'المواهب'),
#  ('الأصدقاء', 'نوافذ'),
#  ('الأول', 'ألحان'),
#  ('الإطلاق', 'special'),
#  ('البقرة', 'البرتقالية'),
#  ('التدريب', 'الرياضي'),
#  ('الحافز', 'الأسود'),
#  ('الحلقة', 'أحجية'),
#  ('الحلقة', 'طريقة'),
#  ('الحلقة', 'كنوز'),
#  ('الحلقة', 'معا'),
#  ('الحلقة', 'مقاطعة'),
#  ('الحلقة', 'موقع'),
#  ('الساحر', 'كرتون'),
#  ('العد', 'من'),
#  ('الفطيرة', 'الضائعة'),
#  ('الفطيرة', 'المفقودة'),
#  ('بالمراسلة', 'كرتون'),
#  ('تعليمي', 'للاطفال'),
#  ('جوقة', 'غنائية'),
#  ('خيرا', 'تحصد'),
#  ('رقم', 'الجزر'),
#  ('ركوب', 'المنطاد'),
#  ('شخصية', 'قوية'),
#  ('شكرا', 'الدمية'),
#  ('عائلة', 'أبريكوت'),
#  ('عائلة', 'أبريكور'),
#  ('عائلة', 'المشمش'),
#  ('عائلة', 'بقرات'),
#  ('عائلةأريكوت', 'رسوم'),
#  ('عربي', 'عائلة'),
#  ('عزنا', 'بطبعنا'),
#  ('في', 'الخدعة'),
#  ('في', 'قريتنا'),
#  ('كرتوني', 'بالعربي'),
#  ('لغز', 'الفطيرة'),
#  ('للأطفال', 'عائلة'),
#  ('للأطفال', 'قلم'),
#  ('للأطفال', 'كرم'),
#  ('للبنات', 'عائلة'),
#  ('مبارة', 'كرة'),
#  ('مجموعة', 'الأذى'),
#  ('مرسال', 'الربيع'),
#  ('مواجهة', 'الخوف'),
#  ('نهاية', 'لها'),
#  ('والأخيرة', 'صخرة'),
#  ('والسعادة', 'مع'),
#  ('动画片', '蜂蜜山的秘密'),
#  ('我们在学习数数', '儿童搞笑卡通'),
#  'animaizinhos',
#  'awful',
#  'caleidoscopio',
#  'chirp',
#  'claymotions',
#  'competiciones',
#  'deeds',
#  'greys',
#  'guaxinins',
#  'infancia',
#  'lala',
#  'ludelandia',
#  'lápiz',
#  'monsikids',
#  'moo',
#  'moocow',
#  'mosaico',
#  'musipaches',
#  'naranjas',
#  'oomka',
#  'paraguas',
#  'paraninos',
#  'plastideas',
#  'rockoons',
#  'récord',
#  'umka',
#  'vaquinha',
#  'vasilisa',
#  'zoh',
#  'الخمول',
#  'الراكون',
#  'القياسي',
#  'المتحرك',
#  'مشمش',
#  '彩泥行动',
#  '彼得和狼',
#  '欢唱小浣熊'}

# %% [markdown]
# # Check detection by UNI- and BI-grams

# %%
reels_plus = df_sql[df_sql.product_id != '']
reels_minus = df_sql[df_sql.product_id == '']

# %%
reels_plus = reels_plus.assign(detected = 0)

# %%
for gram in final_grams_set:
    if type(gram) == str:
        print('str:', gram)
        reels_plus.loc[:,'detected'] += reels_plus['tokens'].apply(lambda cell: int(gram in cell))
    else:
        print('touple:', gram)
        reels_plus.loc[:,'detected'] += reels_plus['bigrams'].apply(lambda cell: int(gram in cell))
# Out:
# touple: ('الإطلاق', 'special')
# touple: ('caracola', 'almohada')
# touple: ('trouble', 'nursery')
# touple: ('massinha', 'au')
# str: récord
# touple: ('caracola', 'dibujos')
# touple: ('números', 'mágicos')
# touple: ('wind', 'instruments')
# touple: ('aprenda', 'os')
# touple: ('favorite', 'games')
# touple: ('pinzas', 'plastilina')
# touple: ('planes', 'learn')
# touple: ('والأخيرة', 'صخرة')
# touple: ('new', 'record')
# touple: ('أغاني', 'أطفال')
# touple: ('whos', 'fastest')
# touple: ('who', 'biggest')
# touple: ('games', 'boys')
# touple: ('games', 'theatre')
# touple: ('juegos', 'deportivos')
# touple: ('лентяйка', 'василиса')
# touple: ('paint', 'brushes')
# touple: ('siete', 'mapaches')
# touple: ('colección', 'grande')
# touple: ('roccoons', 'musical')
# touple: ('الحلقة', 'طريقة')
# touple: ('escondite', 'busca')
# touple: ('al', 'desafío')
# touple: ('pirates', 'abc')
# touple: ('concurso', 'talentos')
# touple: ('عائلة', 'المشمش')
# touple: ('peine', 'ruedas')
# touple: ('walk', 'stand')
# touple: ('juguetes', 'bonitos')
# touple: ('timid', 'brave')
# touple: ('gran', 'historia')
# touple: ('o', 'juguete')
# touple: ('guess', 'riddle')
# touple: ('animales', 'guauguau')
# touple: ('mug', 'invisible')
# touple: ('esperando', 'la')
# touple: ('الحلقة', 'أحجية')
# touple: ('baby', 'ti')
# touple: ('world', 'game')
# touple: ('quiet', 'loud')
# touple: ('count', 'super')
# touple: ('pirata', 'los')
# touple: ('mapaches', 'episodios')
# touple: ('wait', 'rush')
# touple: ('cartoons', 'kittens')
# touple: ('nuevos', 'juegos')
# touple: ('apresurar', 'dibujos')
# touple: ('والسعادة', 'مع')
# touple: ('parte', 'entero')
# touple: ('izquierda', 'derecha')
# touple: ('mood', 'adventures')
# touple: ('migratory', 'birds')
# touple: ('encuentro', 'despedida')
# touple: ('arte', 'dibujos')
# touple: ('عائلة', 'بقرات')
# touple: ('animales', 'cuántas')
# touple: ('guerra', 'los')
# touple: ('الحلقة', 'موقع')
# touple: ('animados', 'cancioneseducativas')
# touple: ('paintbrushes', 'abc')
# touple: ('new', 'things')
# touple: ('infantiles', 'niños')
# touple: ('animals', 'woofwoof')
# touple: ('activities', 'new')
# touple: ('numbers', 'counting')
# str: الخمول
# touple: ('الحافز', 'الأسود')
# touple: ('gancho', 'imán')
# touple: ('للأطفال', 'عائلة')
# touple: ('juegos', 'creativos')
# touple: ('الفطيرة', 'المفقودة')
# touple: ('learning', 'rules')
# touple: ('lo', 'largo')
# touple: ('lleno', 'vacío')
# str: deeds
# touple: ('للبنات', 'عائلة')
# touple: ('vaso', 'plato')
# touple: ('laranja', 'sintamse')
# touple: ('meow', 'lets')
# touple: ('vehículos', 'dinosaurios')
# touple: ('guests', 'gone')
# str: plastideas
# touple: ('carta', 'nuevos')
# touple: ('plato', 'pegatina')
# touple: ('fin', 'del')
# touple: ('للأطفال', 'قلم')
# touple: ('dinosaurs', 'learn')
# touple: ('dishes', 'new')
# touple: ('novo', 'recorde')
# touple: ('linterna', 'pincel')
# touple: ('peques', 'número')
# touple: ('high', 'low')
# touple: ('clima', 'las')
# touple: ('play', 'dance')
# touple: ('الساحر', 'كرتون')
# touple: ('valuable', 'cargo')
# touple: ('nuevo', 'viejo')
# touple: ('ill', 'get')
# touple: ('esponja', 'escobilla')
# touple: ('bowed', 'strings')
# touple: ('عائلةأريكوت', 'رسوم')
# touple: ('toddler', 'learning')
# touple: ('botones', 'maleta')
# touple: ('kids', 'singing')
# touple: ('tirar', 'levantar')
# touple: ('pilotos', 'aventuras')
# touple: ('plucked', 'string')
# touple: ('cartoons', 'orange')
# touple: ('jalar', 'empujar')
# touple: ('cold', 'bit')
# touple: ('مبارة', 'كرة')
# touple: ('massinha', 'gatinhos')
# touple: ('laranja', 'presente')
# touple: ('clay', 'educational')
# str: الراكون
# touple: ('many', 'raisins')
# touple: ('one', 'two')
# touple: ('gatitos', 'estreno')
# touple: ('juegos', 'brillantes')
# touple: ('karaoke', 'lanterns')
# touple: ('atrapar', 'dibujos')
# touple: ('learning', 'play')
# touple: ('remember', 'new')
# touple: ('pequena', 'aranha')
# touple: ('عائلة', 'أبريكور')
# touple: ('fun', 'catchy')
# touple: ('friendship', 'compromise')
# touple: ('meet', 'see')
# touple: ('you', 'orange')
# touple: ('race', 'say')
# touple: ('cenoura', 'aprenda')
# touple: ('vaso', 'dibujos')
# touple: ('cacerola', 'dibujos')
# touple: ('performances', 'new')
# touple: ('learn', 'tell')
# str: paraninos
# touple: ('snowflakes', 'childrens')
# touple: ('ligas', 'pinzas')
# str: 彼得和狼
# touple: ('esp', 'rey')
# touple: ('balde', 'músicas')
# touple: ('rattle', 'sing')
# touple: ('antifaz', 'dibujos')
# touple: ('new', 'caroons')
# str: naranjas
# touple: ('not', 'ski')
# touple: ('desert', 'laziness')
# touple: ('mug', 'clouds')
# touple: ('piramide', 'dibujos')
# touple: ('enojado', 'amable')
# touple: ('4super', 'toonstv')
# touple: ('kids', 'captain')
# touple: ('preguiça', 'toons')
# touple: ('objetos', 'del')
# str: musipaches
# touple: ('empathy', 'emotions')
# str: chirp
# touple: ('جوقة', 'غنائية')
# touple: ('mania', 'عائلة')
# touple: ('في', 'قريتنا')
# touple: ('numbers', 'cartoon')
# touple: ('lápis', 'elástico')
# touple: ('soccer', 'math')
# touple: ('go', 'nursery')
# touple: ('adventure', 'music')
# touple: ('newcartoon', 'nurseryrhymes')
# touple: ('videos', 'lantern')
# touple: ('lápis', 'músicas')
# touple: ('مجموعة', 'الأذى')
# touple: ('educativos', 'dibujos')
# str: caleidoscopio
# touple: ('نهاية', 'لها')
# touple: ('elástica', 'desenho')
# touple: ('toys', 'new')
# touple: ('odd', 'numbers')
# touple: ('whos', 'faster')
# touple: ('throwing', 'catching')
# touple: ('spring', 'miracle')
# touple: ('cartoons', 'can')
# touple: ('secretos', 'del')
# touple: ('beging', 'end')
# touple: ('número', 'um')
# touple: ('games', 'ball')
# touple: ('عائلة', 'أبريكوت')
# touple: ('我们在学习数数', '儿童搞笑卡通')
# touple: ('caracol', 'súper')
# touple: ('free', 'time')
# touple: ('kids', 'keyboard')
# touple: ('عزنا', 'بطبعنا')
# touple: ('take', 'give')
# touple: ('contar', 'números')
# touple: ('ropa', 'para')
# touple: ('defend', 'yourself')
# touple: ('amigos', 'grey')
# str: rockoons
# touple: ('get', 'set')
# touple: ('kids', 'sport')
# touple: ('vehicles', 'helpers')
# touple: ('خيرا', 'تحصد')
# touple: ('games', 'beach')
# touple: ('im', 'house')
# touple: ('aprenda', 'e')
# touple: ('animals', 'teeth')
# touple: ('dishes', 'food')
# touple: ('动画片', '蜂蜜山的秘密')
# touple: ('kids', 'conductors')
# touple: ('vehicles', 'passengers')
# touple: ('row', 'numbers')
# touple: ('yo', 'tesoros')
# touple: ('above', 'below')
# touple: ('instruments', 'kids')
# touple: ('cartoons', 'play')
# touple: ('animals', 'how')
# touple: ('mug', 'sleeping')
# touple: ('save', 'world')
# touple: ('أثقل', 'من')
# touple: ('favoritas', 'dibujos')
# touple: ('رقم', 'الجزر')
# str: animaizinhos
# str: infancia
# str: القياسي
# touple: ('aventuras', 'casitas')
# touple: ('kids', 'unusual')
# touple: ('funny', 'animal')
# touple: ('where', 'wolf')
# touple: ('números', 'plastilina')
# touple: ('teatro', 'dibujos')
# touple: ('cow', 'compilation')
# touple: ('woof', 'super')
# touple: ('juegos', 'fav')
# touple: ('viajes', 'aventuras')
# touple: ('race', 'orange')
# touple: ('letter', 'santa')
# touple: ('animals', 'learn')
# touple: ('food', 'kitchen')
# touple: ('different', 'same')
# touple: ('solo', 'video')
# touple: ('gran', 'ludel')
# touple: ('doh', 'learning')
# touple: ('الأول', 'ألحان')
# touple: ('campamento', 'nuevos')
# touple: ('birdies', 'learning')
# touple: ('biggest', 'animal')
# str: lala
# touple: ('o', 'elástico')
# touple: ('amigos', 'do')
# touple: ('arriba', 'abajo')
# touple: ('me', 'animal')
# touple: ('canción', 'maleta')
# str: moo
# touple: ('here', 'there')
# touple: ('going', 'down')
# touple: ('شكرا', 'الدمية')
# touple: ('massinha', 'dinossauros')
# touple: ('perder', 'encontrar')
# touple: ('ayudando', 'amigos')
# touple: ('easy', 'count')
# touple: ('коллекция', 'даша')
# touple: ('коллекция', 'умка')
# touple: ('الحلقة', 'مقاطعة')
# touple: ('mug', 'maybe')
# touple: ('أتقن', 'عملك')
# touple: ('bebês', 'animazinhos')
# touple: ('animals', 'whos')
# touple: ('cars', 'helpers')
# touple: ('who', 'stronger')
# str: 彩泥行动
# touple: ('hockey', 'stick')
# touple: ('empatía', 'emociones')
# str: monsikids
# touple: ('peter', 'wolf')
# touple: ('مواجهة', 'الخوف')
# touple: ('juegos', 'amigos')
# touple: ('playing', 'new')
# touple: ('الأصدقاء', 'نوافذ')
# touple: ('drop', 'pick')
# touple: ('learning', 'super')
# touple: ('yo', 'dibujos')
# touple: ('haciendo', 'felices')
# touple: ('bádminton', 'con')
# touple: ('friends', 'comedy')
# touple: ('brincar', 'aprender')
# touple: ('cartoon', 'golden')
# touple: ('faster', 'learn')
# touple: ('orden', 'desorden')
# touple: ('platos', 'comida')
# touple: ('ركوب', 'المنطاد')
# touple: ('arctic', 'adventure')
# touple: ('sympathy', 'nursery')
# touple: ('música', 'con')
# touple: ('spa', 'day')
# touple: ('مرسال', 'الربيع')
# touple: ('make', 'play')
# touple: ('part', 'whole')
# touple: ('تعليمي', 'للاطفال')
# touple: ('fools', 'gold')
# touple: ('pirate', 'school')
# touple: ('juegos', 're')
# touple: ('للأطفال', 'كرم')
# touple: ('minute', 'cartoon')
# touple: ('mine', 'yours')
# touple: ('العد', 'من')
# touple: ('battle', 'best')
# touple: ('infantiles', 'canciones')
# touple: ('action', 'packed')
# str: moocow
# touple: ('español', 'música')
# str: competiciones
# touple: ('big', 'toys')
# touple: ('الحلقة', 'كنوز')
# str: claymotions
# touple: ('best', 'ideas')
# touple: ('preguiça', 'terrível')
# touple: ('babies', 'new')
# touple: ('adventure', 'educational')
# touple: ('almuerzo', 'saludable')
# touple: ('بالمراسلة', 'كرتون')
# touple: ('infantil', 'los')
# touple: ('doh', 'cartoon')
# touple: ('الفطيرة', 'الضائعة')
# touple: ('peligro', 'dibujos')
# touple: ('passenger', 'educational')
# str: mosaico
# touple: ('hobby', 'michael')
# touple: ('me', 'soviet')
# touple: ('ideas', 'para')
# touple: ('لغز', 'الفطيرة')
# str: lápiz
# touple: ('break', 'fake')
# touple: ('honey', 'hills')
# touple: ('o', 'balanço')
# touple: ('hot', 'summer')
# touple: ('musipachescómo', 'usar')
# touple: ('new', 'games')
# touple: ('animal', 'learn')
# touple: ('umbrella', 'cloudy')
# touple: ('ray', 'dibujos')
# touple: ('lot', 'bit')
# str: greys
# touple: ('nuevas', 'historias')
# touple: ('toons', 'orange')
# touple: ('amigos', 'dasha')
# str: awful
# touple: ('trouble', 'timmy')
# touple: ('along', 'across')
# touple: ('scrappy', 'new')
# touple: ('animals', 'cartoon')
# touple: ('always', 'never')
# touple: ('animales', 'quién')
# touple: ('pilots', 'best')
# touple: ('underwater', 'plants')
# touple: ('في', 'الخدعة')
# touple: ('missing', 'tree')
# touple: ('guess', 'animal')
# touple: ('new', 'old')
# touple: ('التدريب', 'الرياضي')
# touple: ('misteriosa', 'nuevos')
# touple: ('las', 'vacas')
# touple: ('nueva', 'colección')
# str: umka
# touple: ('musical', 'cartoons')
# str: oomka
# touple: ('kittens', 'learn')
# touple: ('pirata', 'con')
# touple: ('clothes', 'invisible')
# touple: ('البقرة', 'البرتقالية')
# touple: ('niños', 'animados')
# touple: ('español', 'ay')
# touple: ('animals', 'who')
# touple: ('cosas', 'nuevas')
# touple: ('objects', 'new')
# touple: ('lost', 'notebook')
# touple: ('stacking', 'toy')
# touple: ('fan', 'musical')
# touple: ('libre', 'dibujos')
# touple: ('cross', 'kind')
# str: 欢唱小浣熊
# touple: ('first', 'last')
# touple: ('fun', 'counting')
# touple: ('about', 'family')
# touple: ('juegos', 'deporte')
# touple: ('everyone', 'no')
# touple: ('animada', 'educativa')
# touple: ('mug', 'pirate')
# touple: ('siempre', 'nunca')
# touple: ('kids', 'orange')
# str: المتحرك
# touple: ('para', 'amigos')
# touple: ('many', 'legs')
# touple: ('laranja', 'uma')
# touple: ('tímido', 'valiente')
# touple: ('resolviendo', 'problemas')
# touple: ('inside', 'outside')
# str: guaxinins
# str: vasilisa
# touple: ('كرتوني', 'بالعربي')
# touple: ('الحلقة', 'معا')
# touple: ('number', 'learn')
# touple: ('games', 'nursery')
# touple: ('juegos', 'favoritos')
# touple: ('missing', 'pie')
# touple: ('numbers', 'learn')
# touple: ('below', 'above')
# touple: ('chasing', 'running')
# str: paraguas
# touple: ('taco', 'hóquei')
# touple: ('loud', 'quiet')
# touple: ('شخصية', 'قوية')
# str: vaquinha
# touple: ('contar', 'número')
# touple: ('vamos', 'aprender')
# touple: ('hula', 'hula')
# touple: ('maleta', 'corona')
# str: مشمش
# touple: ('dalia', 'ogro')
# touple: ('animals', 'kittens')
# touple: ('winter', 'game')
# touple: ('animados', 'niños')
# touple: ('con', 'plastilina')
# touple: ('fuerte', 'estreno')
# touple: ('games', 'friends')
# str: ludelandia
# touple: ('before', 'behind')
# touple: ('اكتشاف', 'المواهب')
# touple: ('short', 'long')
# touple: ('عربي', 'عائلة')
# touple: ('even', 'numbers')
# touple: ('alone', 'together')
# touple: ('estreia', 'novo')
# touple: ('strong', 'character')
# touple: ('numbers', 'super')
# touple: ('mug', 'black')
# touple: ('brasil', 'orange')
# str: zoh
# touple: ('juegos', 'para')

# %%
reels_plus[reels_plus.detected <1]
# Out:
# Empty DataFrame
# Columns: [yt_reel_id, reel_name, yt_ch_name, cartoon, brand_id, product_id, language, name, tokens, bigrams, detected]
# Index: []
